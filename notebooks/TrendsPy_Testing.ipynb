# %%
from trendspy import Trends, BatchPeriod
import logging
import pandas as pd


class TrendsWrapper:
    """
    A wrapper class for accessing Google Trends data using the TrendsPy library.
    
    Provides reusable methods for popular Google Trends features:
    - Interest over time
    - Interest by region
    - Related queries and topics
    - Real-time trending searches and news
    - Geographic analysis
    
    Usage:
        tw = TrendsWrapper(proxy={"http": "http://proxy.example.com:3128"})
        df = tw.get_interest_over_time(['python', 'javascript'])
    """
    
    def __init__(self, proxy=None):
        """
        Initialize the TrendsWrapper with optional proxy configuration.

        Args:
            proxy (dict or str, optional): Proxy configuration in requests format.
        """
        self.proxy = proxy
        self.trends = Trends(proxy=proxy)
        logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    def get_interest_over_time(self, keywords, timeframe='today 12-m', geo=None, category=None):
        """
        Retrieve interest over time for specified keywords.

        Args:
            keywords (list): List of keywords to analyze.
            timeframe (str): Timeframe for the analysis (default: 'today 12-m').
            geo (str, optional): Geographic region code (default: None).
            category (str, optional): Category ID for the analysis (default: None).
        
        Returns:
            pandas.DataFrame: DataFrame containing interest over time.
        """
        logging.info(f"Fetching interest over time for keywords: {keywords}")
        return self.trends.interest_over_time(
            keywords, timeframe=timeframe, geo=geo, cat=category
        )

    def get_interest_by_region(self, keyword, geo=None, resolution='COUNTRY'):
        """
        Analyze geographic distribution of interest.

        Args:
            keyword (str): Keyword to analyze.
            geo (str, optional): Geographic region code (default: None).
            resolution (str, optional): Geographic resolution ('COUNTRY', 'REGION', 'CITY').
        
        Returns:
            pandas.DataFrame: DataFrame containing interest by region.
        """
        logging.info(f"Fetching interest by region for keyword: {keyword}")
        return self.trends.interest_by_region(
            keyword, geo=geo, resolution=resolution
        )

    def get_related_queries(self, keyword):
        """
        Retrieve related queries for a keyword.

        Args:
            keyword (str): Keyword to analyze.

        Returns:
            dict: Dictionary of related queries (rising and top).
        """
        logging.info(f"Fetching related queries for keyword: {keyword}")
        return self.trends.related_queries(keyword, 
                                           headers={'referer': 'https://www.google.com/'})

    def get_related_topics(self, keyword):
        """
        Retrieve related topics for a keyword.

        Args:
            keyword (str): Keyword to analyze.

        Returns:
            dict: Dictionary of related topics (rising and top).
        """
        logging.info(f"Fetching related topics for keyword: {keyword}")
        return self.trends.related_topics(keyword)

    def get_trending_now(self, geo='US'):
        """
        Retrieve currently trending searches.

        Args:
            geo (str): Geographic region code (default: 'US').

        Returns:
            list: List of trending topics.
        """
        logging.info(f"Fetching trending searches for geo: {geo}")
        return self.trends.trending_now(geo=geo)

    def get_trending_news(self, geo='US'):
        """
        Retrieve trending searches with associated news articles.

        Args:
            geo (str): Geographic region code (default: 'US').

        Returns:
            list: List of trending topics with associated news articles.
        """
        logging.info(f"Fetching trending searches with news for geo: {geo}")
        return self.trends.trending_now_by_rss(geo=geo)

    def get_historical_trends(self, keywords, timeframe=BatchPeriod.Past24H):
        """
        Retrieve independent historical data for multiple keywords.

        Args:
            keywords (list): List of keywords to analyze.
            timeframe (BatchPeriod): Timeframe for the analysis (default: Past24H).

        Returns:
            pandas.DataFrame: DataFrame containing historical trends.
        """
        logging.info(f"Fetching historical trends for keywords: {keywords}")
        return self.trends.trending_now_showcase_timeline(keywords, timeframe=timeframe)

    def search_categories(self, query):
        """
        Search for category IDs based on a query string.

        Args:
            query (str): Query string to search for categories.

        Returns:
            list: List of matching categories with their IDs.
        """
        logging.info(f"Searching for categories matching: {query}")
        return self.trends.categories(find=query)

    def search_locations(self, query):
        """
        Search for location codes based on a query string.

        Args:
            query (str): Query string to search for locations.

        Returns:
            list: List of matching locations with their IDs.
        """
        logging.info(f"Searching for locations matching: {query}")
        return self.trends.geo(find=query)

    def set_proxy(self, proxy):
        """
        Update the proxy configuration.

        Args:
            proxy (dict or str): Proxy configuration in requests format.
        """
        logging.info("Updating proxy configuration.")
        self.trends.set_proxy(proxy)


def parse_related_queries(keyword, trends_wrapper, output_file=None):
    """
    Fetch, parse, and save related queries for a given keyword using TrendsPy.

    Args:
        keyword (str): The search keyword for which related queries are fetched.
        trends_wrapper (TrendsWrapper): An instance of the TrendsWrapper class.
        output_file (str, optional): Path to save the resulting CSV file. Defaults to None.

    Returns:
        pandas.DataFrame: DataFrame containing the parsed related queries.
    
    Columns in DataFrame:
        - query: The related search query text.
        - value: Popularity or growth score of the related query.
        - category: Indicates whether the query is 'top' or 'rising'.
        - keyword: The original keyword used in the search.
    """
    # Fetch related queries
    related_queries = trends_wrapper.get_related_queries(keyword)
    
    # Initialize a list to store parsed data
    data = []

    # Process each category ('top' and 'rising') in the related queries
    for category, queries in related_queries.items():
        if queries is not None:  # Ensure there are queries in the category
            for _, query_data in queries.iterrows():  # Iterate over the DataFrame rows
                data.append({
                    'query': query_data['query'],  # Query text
                    'value': query_data['value'],  # Popularity or growth score
                    'category': category,  # 'top' or 'rising'
                    'keyword': keyword  # The original keyword for traceability
                })

    # Convert the collected data into a pandas DataFrame
    df_related_queries = pd.DataFrame(data)

    # Save the DataFrame to a CSV file if an output file path is provided
    if output_file:
        df_related_queries.to_csv(output_file, index=False)
        print(f"Related queries saved to {output_file}")

    # Return the DataFrame for further analysis
    return df_related_queries

# %%
# Initialize the TrendsWrapper
from trendspy import Trends

tr = Trends()

# Get trending searches for geo='US'
trending_now_us = tr.trending_now(geo='US')

# Print the results
print("Trending Now in the US:")
for topic in trending_now_us:
    print(topic)

# Initialize the API client
tr = Trends()
trends_tech = list(filter(lambda item: 18 in item.topics, trending_now_us))
news = tr.trending_now_news_by_ids(trends_tech[0].news_tokens, max_news=3)

for news_item in news:
    print(news_item, '\n')
# Out:
# Trending Now in the US:
# Keyword        : linda mcmahon
# Geo            : US
# Volume         : 500000 (1000%)
# Timeframe      : 2024-11-19 20:40:00 - now
# Trend keywords : 21 keywords (linda mcmahon,linda mcmahon education,vince mcm...)
# News tokens    : 27 tokens
# Keyword        : dr oz
# Geo            : US
# Volume         : 500000 (1000%)
# Timeframe      : 2024-11-19 20:50:00 - now
# Trend keywords : 23 keywords (dr oz,dr. oz,dr oz trump,mehmet oz,dr oz medica...)
# News tokens    : 27 tokens
# Keyword        : pse outage map
# Geo            : US
# Volume         : 500000 (1000%)
# Timeframe      : 2024-11-19 23:00:00 - now
# Trend keywords : 72 keywords (pse outage map,bay,puget sound energy,power out...)
# News tokens    : 143 tokens
# Keyword        : dalton knecht
# Geo            : US
# Volume         : 200000 (1000%)
# Timeframe      : 2024-11-20 04:30:00 - now
# Trend keywords : 15 keywords (dalton knecht,dalton knecht stats,lakers,los an...)
# News tokens    : 44 tokens
# Keyword        : jay leno
# Geo            : US
# Volume         : 50000 (800%)
# Timeframe      : 2024-11-19 20:10:00 - now
# Trend keywords : 4 keywords (jay leno,jay leno accident,jay leno fall,what h...)
# News tokens    : 6 tokens
# Keyword        : méxico - honduras
# Geo            : US
# Volume         : 500000 (1000%)
# Timeframe      : 2024-11-20 01:50:00 - now
# Trend keywords : 15 keywords (méxico - honduras,mexico vs honduras,honduras v...)
# News tokens    : 40 tokens
# Keyword        : brazil vs uruguay
# Geo            : US
# Volume         : 200000 (1000%)
# Timeframe      : 2024-11-19 21:10:00 - now
# Trend keywords : 18 keywords (brazil vs uruguay,brasil - uruguay,uruguay vs b...)
# News tokens    : 38 tokens
# Keyword        : liam payne funeral
# Geo            : US
# Volume         : 20000 (1000%)
# Timeframe      : 2024-11-20 08:40:00 - now
# Trend keywords : 6 keywords (liam payne funeral,one direction,harry styles,l...)
# News tokens    : 18 tokens
# Keyword        : argentina vs peru
# Geo            : US
# Volume         : 100000 (1000%)
# Timeframe      : 2024-11-19 20:20:00 - now
# Trend keywords : 10 keywords (argentina vs peru,argentina vs,argentina,conmeb...)
# News tokens    : 28 tokens
# Keyword        : group of musical notes
# Geo            : US
# Volume         : 20000 (1000%)
# Timeframe      : 2024-11-20 03:10:00 - now
# Trend keywords : 6 keywords (group of musical notes,group of musical notes n...)
# News tokens    : 7 tokens
# Keyword        : magnetic north pole moving
# Geo            : US
# Volume         : 20000 (700%)
# Timeframe      : 2024-11-19 18:30:00 - now
# Trend keywords : 1 keywords (magnetic north pole moving)
# News tokens    : 1 tokens
# Keyword        : target stock
# Geo            : US
# Volume         : 20000 (900%)
# Timeframe      : 2024-11-20 11:40:00 - now
# Trend keywords : 4 keywords (target stock,tgt stock,tgt,target earnings)
# News tokens    : 9 tokens
# Keyword        : seattle city light outage map
# Geo            : US
# Volume         : 20000 (900%)
# Timeframe      : 2024-11-20 01:20:00 - now
# Trend keywords : 3 keywords (seattle city light outage map,seattle city ligh...)
# News tokens    : 3 tokens
# Keyword        : jazz vs lakers
# Geo            : US
# Volume         : 50000 (1000%)
# Timeframe      : 2024-11-20 03:10:00 - now
# Trend keywords : 15 keywords (jazz vs lakers,lakers games,utah jazz vs lakers...)
# News tokens    : 22 tokens
# Keyword        : susan smith
# Geo            : US
# Volume         : 20000 (1000%)
# Timeframe      : 2024-11-19 19:40:00 - now
# Trend keywords : 2 keywords (susan smith,susan smith parole hearing today)
# News tokens    : 8 tokens
# Keyword        : jose ibarra
# Geo            : US
# Volume         : 20000 (600%)
# Timeframe      : 2024-11-20 03:30:00 - now
# Trend keywords : 7 keywords (jose ibarra,laken riley case,laken riley trial,...)
# News tokens    : 19 tokens
# Keyword        : minecraft movie
# Geo            : US
# Volume         : 20000 (200%)
# Timeframe      : 2024-11-19 20:20:00 - now
# Trend keywords : 1 keywords (minecraft movie)
# News tokens    : 1 tokens
# Keyword        : matt rife
# Geo            : US
# Volume         : 20000 (200%)
# Timeframe      : 2024-11-19 17:20:00 - now
# Trend keywords : 1 keywords (matt rife)
# News tokens    : 2 tokens
# Keyword        : nvidia earnings
# Geo            : US
# Volume         : 50000 (100%)
# Timeframe      : 2024-11-19 20:40:00 - now
# Trend keywords : 11 keywords (nvidia earnings,nvidia earnings report,nvda ear...)
# News tokens    : 36 tokens
# Keyword        : healthcare provider bankruptcies
# Geo            : US
# Volume         : 10000 (600%)
# Timeframe      : 2024-11-20 11:30:00 - now
# Trend keywords : 1 keywords (healthcare provider bankruptcies)
# News tokens    : 1 tokens
# Keyword        : southern california doomsday fish
# Geo            : US
# Volume         : 20000 (300%)
# Timeframe      : 2024-11-19 18:30:00 - now
# Trend keywords : 1 keywords (southern california doomsday fish)
# News tokens    : 1 tokens
# Keyword        : el carro de shakira.com
# Geo            : US
# Volume         : 5000 (500%)
# Timeframe      : 2024-11-20 14:00:00 - now
# Trend keywords : 1 keywords (el carro de shakira.com)
# News tokens    : 1 tokens
# Keyword        : stalker 2 review
# Geo            : US
# Volume         : 20000 (300%)
# Timeframe      : 2024-11-20 04:10:00 - now
# Trend keywords : 5 keywords (stalker 2 review,stalker 2 release time,stalker...)
# News tokens    : 1 tokens
# Keyword        : julianne hough
# Geo            : US
# Volume         : 20000 (300%)
# Timeframe      : 2024-11-20 01:40:00 - now
# Trend keywords : 1 keywords (julianne hough)
# News tokens    : 4 tokens
# Keyword        : lauren sanchez
# Geo            : US
# Volume         : 10000 (700%)
# Timeframe      : 2024-11-20 13:00:00 - now
# Trend keywords : 1 keywords (lauren sanchez)
# News tokens    : 3 tokens
# Keyword        : drones flying over morris county nj
# Geo            : US
# Volume         : 10000 (500%)
# Timeframe      : 2024-11-20 03:30:00 - now
# Trend keywords : 1 keywords (drones flying over morris county nj)
# News tokens    : 1 tokens
# Keyword        : richard gere
# Geo            : US
# Volume         : 10000 (1000%)
# Timeframe      : 2024-11-20 13:30:00 - now
# Trend keywords : 1 keywords (richard gere)
# News tokens    : 7 tokens
# Keyword        : samantha robertson
# Geo            : US
# Volume         : 10000 (400%)
# Timeframe      : 2024-11-20 03:00:00 - now
# Trend keywords : 2 keywords (samantha robertson,jay cutler)
# News tokens    : 4 tokens
# Keyword        : saafir
# Geo            : US
# Volume         : 20000 (200%)
# Timeframe      : 2024-11-19 19:00:00 - now
# Trend keywords : 2 keywords (saafir,saafir rapper)
# News tokens    : 1 tokens
# Keyword        : matt whitaker
# Geo            : US
# Volume         : 5000 (300%)
# Timeframe      : 2024-11-20 15:50:00 - now
# Trend keywords : 2 keywords (matt whitaker,matthew whitaker)
# News tokens    : 1 tokens
# Keyword        : jaguar car
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-20 06:00:00 - now
# Trend keywords : 6 keywords (jaguar car,jaguar rebrand,jaguar logo,jaguar ne...)
# News tokens    : 4 tokens
# Keyword        : nicole murphy
# Geo            : US
# Volume         : 20000 (300%)
# Timeframe      : 2024-11-20 00:40:00 - now
# Trend keywords : 2 keywords (nicole murphy,lisa raye)
# News tokens    : 2 tokens
# Keyword        : morgan freeman
# Geo            : US
# Volume         : 5000 (300%)
# Timeframe      : 2024-11-20 09:40:00 - now
# Trend keywords : 1 keywords (morgan freeman)
# News tokens    : 8 tokens
# Keyword        : spotify wrapped 2024
# Geo            : US
# Volume         : 20000 (100%)
# Timeframe      : 2024-11-20 00:20:00 - now
# Trend keywords : 4 keywords (spotify wrapped 2024,when does spotify wrapped ...)
# News tokens    : 2 tokens
# Keyword        : post malone tour 2025
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-19 21:00:00 - now
# Trend keywords : 1 keywords (post malone tour 2025)
# News tokens    : 1 tokens
# Keyword        : turkey
# Geo            : US
# Volume         : 10000 (50%)
# Timeframe      : 2024-11-20 14:30:00 - now
# Trend keywords : 1 keywords (turkey)
# News tokens    : 27 tokens
# Keyword        : cavaliers vs celtics
# Geo            : US
# Volume         : 200000 (1000%)
# Timeframe      : 2024-11-19 23:30:00 - 2024-11-20 16:50:00
# Trend keywords : 39 keywords (cavaliers vs celtics,celtics vs cavs,cavs,cleve...)
# News tokens    : 66 tokens
# Keyword        : ronan farrow
# Geo            : US
# Volume         : 5000 (500%)
# Timeframe      : 2024-11-20 04:30:00 - now
# Trend keywords : 1 keywords (ronan farrow)
# News tokens    : 1 tokens
# Keyword        : komo news
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 03:20:00 - now
# Trend keywords : 2 keywords (komo news,kiro 7 news)
# News tokens    : 2 tokens
# Keyword        : unrivaled
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 16:00:00 - now
# Trend keywords : 3 keywords (unrivaled,unrivaled basketball,basketball)
# News tokens    : 9 tokens
# Keyword        : comcast
# Geo            : US
# Volume         : 10000 (75%)
# Timeframe      : 2024-11-19 23:40:00 - now
# Trend keywords : 2 keywords (comcast,comcast cable spinoff)
# News tokens    : 1 tokens
# Keyword        : tony campolo
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 02:30:00 - now
# Trend keywords : 1 keywords (tony campolo)
# News tokens    : 1 tokens
# Keyword        : microstrategy stock
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 13:30:00 - now
# Trend keywords : 2 keywords (microstrategy stock,microstrategy)
# News tokens    : 16 tokens
# Keyword        : trans day of remembrance 2024
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-20 12:30:00 - now
# Trend keywords : 2 keywords (trans day of remembrance 2024,transgender day o...)
# News tokens    : 3 tokens
# Keyword        : mexico vs
# Geo            : US
# Volume         : 100000 (1000%)
# Timeframe      : 2024-11-19 23:50:00 - 2024-11-20 13:00:00
# Trend keywords : 24 keywords (mexico vs,mexico soccer,mexico national footbal...)
# News tokens    : 21 tokens
# Keyword        : snow
# Geo            : US
# Volume         : 2000 (75%)
# Timeframe      : 2024-11-20 12:20:00 - now
# Trend keywords : 3 keywords (snow,cleveland weather,milwaukee weather)
# News tokens    : 17 tokens
# Keyword        : dancing with the stars
# Geo            : US
# Volume         : 200000 (75%)
# Timeframe      : 2024-11-20 01:40:00 - 2024-11-20 14:00:00
# Trend keywords : 32 keywords (dancing with the stars,who got eliminated on da...)
# News tokens    : 26 tokens
# Keyword        : jay graber
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 04:50:00 - now
# Trend keywords : 1 keywords (jay graber)
# News tokens    : 2 tokens
# Keyword        : kyle busch
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 06:10:00 - now
# Trend keywords : 1 keywords (kyle busch)
# News tokens    : 6 tokens
# Keyword        : hulk hogan
# Geo            : US
# Volume         : 1000 (200%)
# Timeframe      : 2024-11-20 16:40:00 - now
# Trend keywords : 1 keywords (hulk hogan)
# News tokens    : 7 tokens
# Keyword        : jersey mike's subs
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 15:50:00 - now
# Trend keywords : 2 keywords (jersey mike's subs,jersey mike's)
# News tokens    : 1 tokens
# Keyword        : chile vs venezuela
# Geo            : US
# Volume         : 50000 (1000%)
# Timeframe      : 2024-11-19 21:40:00 - 2024-11-20 14:00:00
# Trend keywords : 8 keywords (chile vs venezuela,chile - venezuela,venezuela ...)
# News tokens    : 6 tokens
# Keyword        : argentina - perú
# Geo            : US
# Volume         : 50000 (1000%)
# Timeframe      : 2024-11-19 23:00:00 - 2024-11-20 13:10:00
# Trend keywords : 6 keywords (argentina - perú,eliminatorias copa del mundo,e...)
# News tokens    : 26 tokens
# Keyword        : dallas cowboys football
# Geo            : US
# Volume         : 1000 (100%)
# Timeframe      : 2024-11-20 16:40:00 - now
# Trend keywords : 1 keywords (dallas cowboys football)
# News tokens    : 5 tokens
# Keyword        : playstation portal
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-20 06:00:00 - now
# Trend keywords : 1 keywords (playstation portal)
# News tokens    : 1 tokens
# Keyword        : sarah mcbride
# Geo            : US
# Volume         : 50000 (1000%)
# Timeframe      : 2024-11-20 00:10:00 - 2024-11-20 15:10:00
# Trend keywords : 3 keywords (sarah mcbride,sarah mcbride congress,transgende...)
# News tokens    : 6 tokens
# Keyword        : pelicans vs mavericks
# Geo            : US
# Volume         : 20000 (700%)
# Timeframe      : 2024-11-20 01:10:00 - 2024-11-20 16:50:00
# Trend keywords : 1 keywords (pelicans vs mavericks)
# News tokens    : 2 tokens
# Keyword        : keanu koht
# Geo            : US
# Volume         : 2000 (75%)
# Timeframe      : 2024-11-19 20:30:00 - now
# Trend keywords : 1 keywords (keanu koht)
# News tokens    : 1 tokens
# Keyword        : thunder vs spurs
# Geo            : US
# Volume         : 50000 (700%)
# Timeframe      : 2024-11-20 02:10:00 - 2024-11-20 16:20:00
# Trend keywords : 18 keywords (thunder vs spurs,keldon johnson,spurs,harrison ...)
# News tokens    : 50 tokens
# Keyword        : purdue vs marquette
# Geo            : US
# Volume         : 50000 (200%)
# Timeframe      : 2024-11-20 02:00:00 - 2024-11-20 14:50:00
# Trend keywords : 6 keywords (purdue vs marquette,marquette basketball,purdue...)
# News tokens    : 7 tokens
# Keyword        : yankees juan soto
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 16:50:00 - now
# Trend keywords : 3 keywords (yankees juan soto,juan soto yankees,juan soto mlb)
# News tokens    : 11 tokens
# Keyword        : colombia - ecuador
# Geo            : US
# Volume         : 100000 (1000%)
# Timeframe      : 2024-11-19 22:10:00 - 2024-11-20 12:00:00
# Trend keywords : 12 keywords (colombia - ecuador,colombia vs,eliminatorias,co...)
# News tokens    : 36 tokens
# Keyword        : nuggets vs grizzlies
# Geo            : US
# Volume         : 20000 (1000%)
# Timeframe      : 2024-11-20 00:50:00 - 2024-11-20 13:10:00
# Trend keywords : 5 keywords (nuggets vs grizzlies,nuggets,santi aldama,micha...)
# News tokens    : 13 tokens
# Keyword        : mega millions
# Geo            : US
# Volume         : 20000 (50%)
# Timeframe      : 2024-11-20 10:40:00 - 2024-11-20 14:00:00
# Trend keywords : 11 keywords (mega millions,mega millions lottery,mega millio...)
# News tokens    : 20 tokens
# Keyword        : jim montgomery
# Geo            : US
# Volume         : 50000 (500%)
# Timeframe      : 2024-11-19 18:50:00 - 2024-11-20 14:20:00
# Trend keywords : 9 keywords (jim montgomery,joe sacco,joe sacco hockey,joe s...)
# News tokens    : 22 tokens
# Keyword        : hornets vs nets
# Geo            : US
# Volume         : 50000 (600%)
# Timeframe      : 2024-11-20 00:10:00 - 2024-11-20 14:10:00
# Trend keywords : 10 keywords (hornets vs nets,hornets,lamelo ball stats,nets ...)
# News tokens    : 31 tokens
# Keyword        : jose siri
# Geo            : US
# Volume         : 20000 (600%)
# Timeframe      : 2024-11-19 21:20:00 - 2024-11-20 15:00:00
# Trend keywords : 6 keywords (jose siri,eric orze,mets,ny mets,major league b...)
# News tokens    : 32 tokens
# Keyword        : billie eilish
# Geo            : US
# Volume         : 5000 (75%)
# Timeframe      : 2024-11-20 07:00:00 - now
# Trend keywords : 1 keywords (billie eilish)
# News tokens    : 7 tokens
# Keyword        : israel hezbollah ceasefire
# Geo            : US
# Volume         : 5000 (300%)
# Timeframe      : 2024-11-20 03:50:00 - 2024-11-20 16:10:00
# Trend keywords : 1 keywords (israel hezbollah ceasefire)
# News tokens    : 1 tokens
# Keyword        : spacex launch
# Geo            : US
# Volume         : 50000 (1000%)
# Timeframe      : 2024-11-19 20:40:00 - 2024-11-20 02:20:00
# Trend keywords : 23 keywords (spacex launch,space x,spacex starship launch,sp...)
# News tokens    : 40 tokens
# Keyword        : ray lewis
# Geo            : US
# Volume         : 2000 (200%)
# Timeframe      : 2024-11-20 14:40:00 - 2024-11-20 17:00:00
# Trend keywords : 1 keywords (ray lewis)
# News tokens    : 1 tokens
# Keyword        : peru vs argentina
# Geo            : US
# Volume         : 20000 (400%)
# Timeframe      : 2024-11-19 20:30:00 - 2024-11-20 13:50:00
# Trend keywords : 1 keywords (peru vs argentina)
# News tokens    : 10 tokens
# Keyword        : danny amendola
# Geo            : US
# Volume         : 50000 (200%)
# Timeframe      : 2024-11-20 01:30:00 - 2024-11-20 07:30:00
# Trend keywords : 3 keywords (danny amendola,ilona maher,ilona maher partner)
# News tokens    : 6 tokens
# Keyword        : wayne
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-19 22:10:00 - 2024-11-20 16:40:00
# Trend keywords : 1 keywords (wayne)
# News tokens    : 10 tokens
# Keyword        : king 5 news
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 03:50:00 - 2024-11-20 17:10:00
# Trend keywords : 1 keywords (king 5 news)
# News tokens    : 2 tokens
# Keyword        : jordan peterson
# Geo            : US
# Volume         : 5000 (300%)
# Timeframe      : 2024-11-20 01:10:00 - 2024-11-20 14:50:00
# Trend keywords : 1 keywords (jordan peterson)
# News tokens    : 5 tokens
# Keyword        : mexico
# Geo            : US
# Volume         : 20000 (500%)
# Timeframe      : 2024-11-20 01:00:00 - 2024-11-20 12:40:00
# Trend keywords : 1 keywords (mexico)
# News tokens    : 9 tokens
# Keyword        : bolivia vs paraguay
# Geo            : US
# Volume         : 50000 (1000%)
# Timeframe      : 2024-11-19 19:20:00 - 2024-11-20 02:20:00
# Trend keywords : 5 keywords (bolivia vs paraguay,bolivia - paraguay,paraguay...)
# News tokens    : 13 tokens
# Keyword        : cma awards
# Geo            : US
# Volume         : 5000 (50%)
# Timeframe      : 2024-11-20 01:00:00 - now
# Trend keywords : 4 keywords (cma awards,lainey wilson,thomas rhett,country m...)
# News tokens    : 19 tokens
# Keyword        : real housewives of beverly hills
# Geo            : US
# Volume         : 10000 (200%)
# Timeframe      : 2024-11-19 22:50:00 - 2024-11-20 13:30:00
# Trend keywords : 3 keywords (real housewives of beverly hills,rhobh,dorit ke...)
# News tokens    : 15 tokens
# Keyword        : how to train your dragon movie trailer
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-20 01:20:00 - 2024-11-20 13:20:00
# Trend keywords : 5 keywords (how to train your dragon movie trailer,httyd li...)
# News tokens    : 3 tokens
# Keyword        : nba cup standings
# Geo            : US
# Volume         : 5000 (300%)
# Timeframe      : 2024-11-20 02:00:00 - 2024-11-20 14:00:00
# Trend keywords : 1 keywords (nba cup standings)
# News tokens    : 6 tokens
# Keyword        : christmas music
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-20 13:30:00 - 2024-11-20 17:10:00
# Trend keywords : 1 keywords (christmas music)
# News tokens    : 11 tokens
# Keyword        : mgk
# Geo            : US
# Volume         : 20000 (1000%)
# Timeframe      : 2024-11-20 02:00:00 - 2024-11-20 07:40:00
# Trend keywords : 2 keywords (mgk,machine gun kelly)
# News tokens    : 6 tokens
# Keyword        : rangers vs canucks
# Geo            : US
# Volume         : 10000 (200%)
# Timeframe      : 2024-11-20 03:00:00 - 2024-11-20 14:10:00
# Trend keywords : 6 keywords (rangers vs canucks,ny rangers,new york rangers,...)
# News tokens    : 25 tokens
# Keyword        : seth mclaughlin
# Geo            : US
# Volume         : 10000 (300%)
# Timeframe      : 2024-11-20 01:20:00 - 2024-11-20 15:20:00
# Trend keywords : 1 keywords (seth mclaughlin)
# News tokens    : 1 tokens
# Keyword        : maharashtra election 2024
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 05:30:00 - 2024-11-20 17:00:00
# Trend keywords : 1 keywords (maharashtra election 2024)
# News tokens    : 1 tokens
# Keyword        : eliminatorias conmebol
# Geo            : US
# Volume         : 20000 (600%)
# Timeframe      : 2024-11-19 21:40:00 - 2024-11-20 03:10:00
# Trend keywords : 6 keywords (eliminatorias conmebol,conmebol eliminatorias,t...)
# News tokens    : 13 tokens
# Keyword        : mcrib
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 16:30:00 - now
# Trend keywords : 1 keywords (mcrib)
# News tokens    : 2 tokens
# Keyword        : woody johnson
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-19 17:20:00 - 2024-11-20 16:50:00
# Trend keywords : 1 keywords (woody johnson)
# News tokens    : 6 tokens
# Keyword        : russell westbrook
# Geo            : US
# Volume         : 10000 (500%)
# Timeframe      : 2024-11-20 03:40:00 - 2024-11-20 13:00:00
# Trend keywords : 2 keywords (russell westbrook,westbrook)
# News tokens    : 4 tokens
# Keyword        : lakers vs jazz
# Geo            : US
# Volume         : 5000 (300%)
# Timeframe      : 2024-11-20 02:50:00 - 2024-11-20 13:50:00
# Trend keywords : 1 keywords (lakers vs jazz)
# News tokens    : 4 tokens
# Keyword        : pink tote mom tiktok
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 04:40:00 - 2024-11-20 17:10:00
# Trend keywords : 1 keywords (pink tote mom tiktok)
# News tokens    : 1 tokens
# Keyword        : corinthians vs cruzeiro
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 13:10:00 - 2024-11-20 17:00:00
# Trend keywords : 1 keywords (corinthians vs cruzeiro)
# News tokens    : 3 tokens
# Keyword        : ryan eggold
# Geo            : US
# Volume         : 2000 (200%)
# Timeframe      : 2024-11-20 14:30:00 - 2024-11-20 16:40:00
# Trend keywords : 1 keywords (ryan eggold)
# News tokens    : 1 tokens
# Keyword        : bill clinton
# Geo            : US
# Volume         : 10000 (1000%)
# Timeframe      : 2024-11-20 05:00:00 - 2024-11-20 11:50:00
# Trend keywords : 1 keywords (bill clinton)
# News tokens    : 12 tokens
# Keyword        : storm shadow missile
# Geo            : US
# Volume         : 1000 (50%)
# Timeframe      : 2024-11-20 14:50:00 - now
# Trend keywords : 1 keywords (storm shadow missile)
# News tokens    : 3 tokens
# Keyword        : social security payments
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 03:40:00 - 2024-11-20 17:00:00
# Trend keywords : 1 keywords (social security payments)
# News tokens    : 6 tokens
# Keyword        : ffxiv mobile
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 02:30:00 - 2024-11-20 13:30:00
# Trend keywords : 3 keywords (ffxiv mobile,ff14 mobile,final fantasy xiv mobile)
# News tokens    : 1 tokens
# Keyword        : jeff bezos
# Geo            : US
# Volume         : 2000 (200%)
# Timeframe      : 2024-11-20 13:10:00 - 2024-11-20 17:10:00
# Trend keywords : 1 keywords (jeff bezos)
# News tokens    : 5 tokens
# Keyword        : cfp rankings today
# Geo            : US
# Volume         : 50000 (200%)
# Timeframe      : 2024-11-19 23:30:00 - 2024-11-20 13:50:00
# Trend keywords : 15 keywords (cfp rankings today,cfp bracket,cfp rankings,cfb...)
# News tokens    : 37 tokens
# Keyword        : jinx fixes everything act 2
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-19 19:30:00 - 2024-11-20 11:00:00
# Trend keywords : 2 keywords (jinx fixes everything act 2,jinx fixes everythi...)
# News tokens    : 1 tokens
# Keyword        : miami ohio football
# Geo            : US
# Volume         : 20000 (300%)
# Timeframe      : 2024-11-20 01:10:00 - 2024-11-20 13:00:00
# Trend keywords : 6 keywords (miami ohio football,northern il vs miami oh,niu...)
# News tokens    : 6 tokens
# Keyword        : macy's thanksgiving day parade
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-20 13:30:00 - 2024-11-20 17:10:00
# Trend keywords : 1 keywords (macy's thanksgiving day parade)
# News tokens    : 6 tokens
# Keyword        : lipscomb vs kentucky
# Geo            : US
# Volume         : 20000 (300%)
# Timeframe      : 2024-11-20 02:00:00 - 2024-11-20 13:20:00
# Trend keywords : 9 keywords (lipscomb vs kentucky,uk basketball,uk basketbal...)
# News tokens    : 11 tokens
# Keyword        : maureen mcdermott uri accident
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-19 23:40:00 - 2024-11-20 11:20:00
# Trend keywords : 1 keywords (maureen mcdermott uri accident)
# News tokens    : 1 tokens
# Keyword        : seattle public schools
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 13:30:00 - 2024-11-20 16:20:00
# Trend keywords : 1 keywords (seattle public schools)
# News tokens    : 2 tokens
# Keyword        : stimulus check 2024
# Geo            : US
# Volume         : 5000 (75%)
# Timeframe      : 2024-11-20 11:00:00 - 2024-11-20 16:00:00
# Trend keywords : 3 keywords (stimulus check 2024,stimulus checks,irs stimulu...)
# News tokens    : 3 tokens
# Keyword        : hollywood brown
# Geo            : US
# Volume         : 2000 (200%)
# Timeframe      : 2024-11-20 11:50:00 - 2024-11-20 15:30:00
# Trend keywords : 1 keywords (hollywood brown)
# News tokens    : 3 tokens
# Keyword        : school delays
# Geo            : US
# Volume         : 2000 (600%)
# Timeframe      : 2024-11-20 10:20:00 - 2024-11-20 14:10:00
# Trend keywords : 2 keywords (school delays,spokane weather)
# News tokens    : 9 tokens
# Keyword        : how many days until christmas
# Geo            : US
# Volume         : 10000 (75%)
# Timeframe      : 2024-11-20 12:20:00 - 2024-11-20 14:00:00
# Trend keywords : 3 keywords (how many days until christmas,days until christ...)
# News tokens    : 1 tokens
# Keyword        : al horford
# Geo            : US
# Volume         : 10000 (300%)
# Timeframe      : 2024-11-19 23:30:00 - 2024-11-20 11:10:00
# Trend keywords : 1 keywords (al horford)
# News tokens    : 2 tokens
# Keyword        : wild vs blues
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 00:50:00 - 2024-11-20 13:20:00
# Trend keywords : 1 keywords (wild vs blues)
# News tokens    : 4 tokens
# Keyword        : corinthians x cruzeiro
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 13:10:00 - 2024-11-20 15:50:00
# Trend keywords : 3 keywords (corinthians x cruzeiro,cruzeiro,corinthians)
# News tokens    : 14 tokens
# Keyword        : simone biles
# Geo            : US
# Volume         : 10000 (200%)
# Timeframe      : 2024-11-19 22:30:00 - 2024-11-20 11:20:00
# Trend keywords : 2 keywords (simone biles,simone biles baby)
# News tokens    : 6 tokens
# Keyword        : nio stock
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 10:40:00 - 2024-11-20 15:40:00
# Trend keywords : 1 keywords (nio stock)
# News tokens    : 8 tokens
# Keyword        : jeff hobbs rob peace
# Geo            : US
# Volume         : 5000 (50%)
# Timeframe      : 2024-11-20 02:30:00 - 2024-11-20 15:40:00
# Trend keywords : 2 keywords (jeff hobbs rob peace,robert peace)
# News tokens    : 1 tokens
# Keyword        : jt miller
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-19 18:20:00 - 2024-11-20 13:20:00
# Trend keywords : 1 keywords (jt miller)
# News tokens    : 1 tokens
# Keyword        : central michigan football
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-20 01:00:00 - 2024-11-20 12:20:00
# Trend keywords : 4 keywords (central michigan football,western michigan foot...)
# News tokens    : 6 tokens
# Keyword        : vladimir putin
# Geo            : US
# Volume         : 5000 (1000%)
# Timeframe      : 2024-11-20 06:20:00 - 2024-11-20 11:10:00
# Trend keywords : 1 keywords (vladimir putin)
# News tokens    : 11 tokens
# Keyword        : argentina fc
# Geo            : US
# Volume         : 20000 (900%)
# Timeframe      : 2024-11-19 23:50:00 - 2024-11-20 03:20:00
# Trend keywords : 1 keywords (argentina fc)
# News tokens    : 2 tokens
# Keyword        : james franco
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-19 20:20:00 - 2024-11-20 10:50:00
# Trend keywords : 1 keywords (james franco)
# News tokens    : 4 tokens
# Keyword        : tren de aragua
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 10:30:00 - 2024-11-20 15:20:00
# Trend keywords : 3 keywords (tren de aragua,knox county tn,knox county tenne...)
# News tokens    : 11 tokens
# Keyword        : colombia
# Geo            : US
# Volume         : 20000 (400%)
# Timeframe      : 2024-11-19 23:00:00 - 2024-11-20 02:40:00
# Trend keywords : 13 keywords (colombia,ecuador vs,where to watch colombia nat...)
# News tokens    : 22 tokens
# Keyword        : lightning vs penguins
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-19 23:50:00 - 2024-11-20 13:00:00
# Trend keywords : 1 keywords (lightning vs penguins)
# News tokens    : 3 tokens
# Keyword        : putin
# Geo            : US
# Volume         : 10000 (300%)
# Timeframe      : 2024-11-20 04:00:00 - 2024-11-20 12:50:00
# Trend keywords : 3 keywords (putin,nuclear war,putin news)
# News tokens    : 26 tokens
# Keyword        : charles manson
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-19 23:00:00 - 2024-11-20 09:30:00
# Trend keywords : 1 keywords (charles manson)
# News tokens    : 1 tokens
# Keyword        : microsoft flight simulator login queue
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 02:10:00 - 2024-11-20 13:20:00
# Trend keywords : 3 keywords (microsoft flight simulator login queue,login qu...)
# News tokens    : 5 tokens
# Keyword        : msu basketball
# Geo            : US
# Volume         : 10000 (700%)
# Timeframe      : 2024-11-20 01:00:00 - 2024-11-20 03:50:00
# Trend keywords : 5 keywords (msu basketball,samford vs mi state,michigan sta...)
# News tokens    : 9 tokens
# Keyword        : darius garland
# Geo            : US
# Volume         : 10000 (700%)
# Timeframe      : 2024-11-19 23:40:00 - 2024-11-20 03:50:00
# Trend keywords : 1 keywords (darius garland)
# News tokens    : 3 tokens
# Keyword        : sebastian stan
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 02:30:00 - 2024-11-20 14:00:00
# Trend keywords : 1 keywords (sebastian stan)
# News tokens    : 6 tokens
# Keyword        : nyt connections hints november 19
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 02:00:00 - 2024-11-20 12:00:00
# Trend keywords : 2 keywords (nyt connections hints november 19,nyt connectio...)
# News tokens    : 2 tokens
# Keyword        : akron football
# Geo            : US
# Volume         : 10000 (200%)
# Timeframe      : 2024-11-19 23:10:00 - 2024-11-20 04:30:00
# Trend keywords : 4 keywords (akron football,kent state football,akron vs ken...)
# News tokens    : 5 tokens
# Keyword        : ethiopia
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-20 10:50:00 - 2024-11-20 17:00:00
# Trend keywords : 1 keywords (ethiopia)
# News tokens    : 8 tokens
# Keyword        : john elway
# Geo            : US
# Volume         : 2000 (200%)
# Timeframe      : 2024-11-20 13:50:00 - 2024-11-20 15:40:00
# Trend keywords : 1 keywords (john elway)
# News tokens    : 3 tokens
# Keyword        : social security fairness act senate
# Geo            : US
# Volume         : 5000 (300%)
# Timeframe      : 2024-11-19 18:20:00 - 2024-11-20 11:20:00
# Trend keywords : 1 keywords (social security fairness act senate)
# News tokens    : 1 tokens
# Keyword        : donovan mitchell
# Geo            : US
# Volume         : 10000 (400%)
# Timeframe      : 2024-11-20 00:20:00 - 2024-11-20 03:40:00
# Trend keywords : 1 keywords (donovan mitchell)
# News tokens    : 8 tokens
# Keyword        : hungary vs germany
# Geo            : US
# Volume         : 10000 (500%)
# Timeframe      : 2024-11-19 18:50:00 - 2024-11-20 00:20:00
# Trend keywords : 2 keywords (hungary vs germany,germany vs hungary)
# News tokens    : 4 tokens
# Keyword        : where to watch mexico national football team vs honduras national football team
# Geo            : US
# Volume         : 10000 (1000%)
# Timeframe      : 2024-11-20 02:30:00 - 2024-11-20 05:40:00
# Trend keywords : 1 keywords (where to watch mexico national football team vs...)
# News tokens    : 2 tokens
# Keyword        : austin reaves
# Geo            : US
# Volume         : 2000 (400%)
# Timeframe      : 2024-11-20 04:30:00 - 2024-11-20 10:50:00
# Trend keywords : 1 keywords (austin reaves)
# News tokens    : 5 tokens
# Keyword        : joey graziadei
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 01:20:00 - 2024-11-20 07:30:00
# Trend keywords : 1 keywords (joey graziadei)
# News tokens    : 6 tokens
# Keyword        : austin seibert
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 08:20:00 - 2024-11-20 13:40:00
# Trend keywords : 3 keywords (austin seibert,week 12 defense rankings,defense...)
# News tokens    : 5 tokens
# Keyword        : kyiv
# Geo            : US
# Volume         : 5000 (75%)
# Timeframe      : 2024-11-20 08:20:00 - 2024-11-20 14:50:00
# Trend keywords : 6 keywords (kyiv,ukraine war news,russian missiles,ukrainia...)
# News tokens    : 26 tokens
# Keyword        : brandon durham
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 05:30:00 - 2024-11-20 13:50:00
# Trend keywords : 2 keywords (brandon durham,brandon durham shooting)
# News tokens    : 1 tokens
# Keyword        : lauri markkanen
# Geo            : US
# Volume         : 5000 (400%)
# Timeframe      : 2024-11-20 02:50:00 - 2024-11-20 07:30:00
# Trend keywords : 1 keywords (lauri markkanen)
# News tokens    : 4 tokens
# Keyword        : mohini dey
# Geo            : US
# Volume         : 1000 (75%)
# Timeframe      : 2024-11-20 11:20:00 - 2024-11-20 17:10:00
# Trend keywords : 1 keywords (mohini dey)
# News tokens    : 1 tokens
# Keyword        : uncw vs kansas
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 03:30:00 - 2024-11-20 13:20:00
# Trend keywords : 4 keywords (uncw vs kansas,ku basketball,uncw basketball,un...)
# News tokens    : 10 tokens
# Keyword        : cameron johnson
# Geo            : US
# Volume         : 10000 (200%)
# Timeframe      : 2024-11-20 02:10:00 - 2024-11-20 08:10:00
# Trend keywords : 2 keywords (cameron johnson,nets)
# News tokens    : 14 tokens
# Keyword        : adam ray
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-19 23:30:00 - 2024-11-20 07:50:00
# Trend keywords : 1 keywords (adam ray)
# News tokens    : 2 tokens
# Keyword        : alan bersten
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 01:30:00 - 2024-11-20 07:50:00
# Trend keywords : 1 keywords (alan bersten)
# News tokens    : 4 tokens
# Keyword        : ariana grande
# Geo            : US
# Volume         : 20000 (100%)
# Timeframe      : 2024-11-20 03:10:00 - 2024-11-20 04:50:00
# Trend keywords : 5 keywords (ariana grande,wicked,cynthia erivo,wicked movie...)
# News tokens    : 29 tokens
# Keyword        : bowen yang
# Geo            : US
# Volume         : 1000 (100%)
# Timeframe      : 2024-11-20 13:50:00 - 2024-11-20 16:30:00
# Trend keywords : 1 keywords (bowen yang)
# News tokens    : 9 tokens
# Keyword        : wsdot
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-20 05:00:00 - 2024-11-20 16:40:00
# Trend keywords : 2 keywords (wsdot,charlotte weather)
# News tokens    : 9 tokens
# Keyword        : kelly ortberg
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 16:50:00 - 2024-11-20 17:10:00
# Trend keywords : 1 keywords (kelly ortberg)
# News tokens    : 4 tokens
# Keyword        : nikola jokic
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-20 01:20:00 - 2024-11-20 05:00:00
# Trend keywords : 2 keywords (nikola jokic,jokic)
# News tokens    : 8 tokens
# Keyword        : ios 18.1.1
# Geo            : US
# Volume         : 1000 (75%)
# Timeframe      : 2024-11-20 05:50:00 - 2024-11-20 14:10:00
# Trend keywords : 1 keywords (ios 18.1.1)
# News tokens    : 6 tokens
# Keyword        : marc rowan
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 03:40:00 - 2024-11-20 15:30:00
# Trend keywords : 2 keywords (marc rowan,treasury secretary)
# News tokens    : 6 tokens
# Keyword        : motortrend roadkill
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-20 15:10:00 - 2024-11-20 16:20:00
# Trend keywords : 1 keywords (motortrend roadkill)
# News tokens    : 1 tokens
# Keyword        : rita moreno
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-19 19:20:00 - 2024-11-20 14:40:00
# Trend keywords : 2 keywords (rita moreno,mattel)
# News tokens    : 7 tokens
# Keyword        : school closures seattle
# Geo            : US
# Volume         : 1000 (75%)
# Timeframe      : 2024-11-20 13:10:00 - 2024-11-20 15:10:00
# Trend keywords : 2 keywords (school closures seattle,seattle school closures)
# News tokens    : 5 tokens
# Keyword        : ana gasteyer
# Geo            : US
# Volume         : 1000 (75%)
# Timeframe      : 2024-11-20 12:50:00 - 2024-11-20 15:30:00
# Trend keywords : 1 keywords (ana gasteyer)
# News tokens    : 2 tokens
# Keyword        : snoqualmie pass weather
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 04:10:00 - 2024-11-20 11:40:00
# Trend keywords : 2 keywords (snoqualmie pass weather,snoqualmie pass)
# News tokens    : 2 tokens
# Keyword        : brasil vs uruguay
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 00:30:00 - 2024-11-20 11:20:00
# Trend keywords : 4 keywords (brasil vs uruguay,brasil vs. uruguay,brasil uru...)
# News tokens    : 6 tokens
# Keyword        : houston astros
# Geo            : US
# Volume         : 10000 (200%)
# Timeframe      : 2024-11-19 18:30:00 - 2024-11-20 01:20:00
# Trend keywords : 1 keywords (houston astros)
# News tokens    : 6 tokens
# Keyword        : kristin cavallari
# Geo            : US
# Volume         : 1000 (100%)
# Timeframe      : 2024-11-20 10:20:00 - 2024-11-20 14:00:00
# Trend keywords : 1 keywords (kristin cavallari)
# News tokens    : 5 tokens
# Keyword        : stephen nedoroscik
# Geo            : US
# Volume         : 10000 (100%)
# Timeframe      : 2024-11-20 01:50:00 - 2024-11-20 07:00:00
# Trend keywords : 2 keywords (stephen nedoroscik,stephen dancing with the stars)
# News tokens    : 5 tokens
# Keyword        : tarjeta roja
# Geo            : US
# Volume         : 5000 (600%)
# Timeframe      : 2024-11-19 22:50:00 - 2024-11-20 03:30:00
# Trend keywords : 1 keywords (tarjeta roja)
# News tokens    : 3 tokens
# Keyword        : school closings and delays
# Geo            : US
# Volume         : 2000 (200%)
# Timeframe      : 2024-11-20 11:00:00 - 2024-11-20 14:10:00
# Trend keywords : 5 keywords (school closings and delays,school closings,dela...)
# News tokens    : 10 tokens
# Keyword        : shai gilgeous-alexander
# Geo            : US
# Volume         : 5000 (400%)
# Timeframe      : 2024-11-20 02:20:00 - 2024-11-20 05:50:00
# Trend keywords : 1 keywords (shai gilgeous-alexander)
# News tokens    : 7 tokens
# Keyword        : collin sexton
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 03:00:00 - 2024-11-20 10:20:00
# Trend keywords : 1 keywords (collin sexton)
# News tokens    : 3 tokens
# Keyword        : blackhawks
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 02:20:00 - 2024-11-20 05:10:00
# Trend keywords : 4 keywords (blackhawks,winter classic 2025,chicago blackhaw...)
# News tokens    : 15 tokens
# Keyword        : vix
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 00:00:00 - 2024-11-20 04:50:00
# Trend keywords : 1 keywords (vix)
# News tokens    : 5 tokens
# Keyword        : allegiant airlines
# Geo            : US
# Volume         : 10000 (50%)
# Timeframe      : 2024-11-19 17:30:00 - 2024-11-20 13:00:00
# Trend keywords : 3 keywords (allegiant airlines,allegiant,allegiant air)
# News tokens    : 2 tokens
# Keyword        : high potential new episodes
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 03:50:00 - 2024-11-20 10:20:00
# Trend keywords : 2 keywords (high potential new episodes,high potential epis...)
# News tokens    : 2 tokens
# Keyword        : lamelo ball
# Geo            : US
# Volume         : 10000 (700%)
# Timeframe      : 2024-11-20 02:30:00 - 2024-11-20 04:00:00
# Trend keywords : 2 keywords (lamelo ball,lamelo)
# News tokens    : 7 tokens
# Keyword        : we who wrestle with god
# Geo            : US
# Volume         : 2000 (300%)
# Timeframe      : 2024-11-20 01:10:00 - 2024-11-20 14:50:00
# Trend keywords : 1 keywords (we who wrestle with god)
# News tokens    : 1 tokens
# Keyword        : bozoma saint john
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 01:50:00 - 2024-11-20 09:20:00
# Trend keywords : 1 keywords (bozoma saint john)
# News tokens    : 3 tokens
# Keyword        : bernard arnault
# Geo            : US
# Volume         : 1000 (75%)
# Timeframe      : 2024-11-20 06:20:00 - 2024-11-20 14:10:00
# Trend keywords : 1 keywords (bernard arnault)
# News tokens    : 5 tokens
# Keyword        : goldie hawn
# Geo            : US
# Volume         : 1000 (400%)
# Timeframe      : 2024-11-20 13:30:00 - 2024-11-20 14:40:00
# Trend keywords : 1 keywords (goldie hawn)
# News tokens    : 7 tokens
# Keyword        : russia missile
# Geo            : US
# Volume         : 5000 (1000%)
# Timeframe      : 2024-11-20 07:40:00 - 2024-11-20 10:40:00
# Trend keywords : 5 keywords (russia missile,missiles russia,war,missile ukra...)
# News tokens    : 36 tokens
# Keyword        : keyonte george
# Geo            : US
# Volume         : 2000 (200%)
# Timeframe      : 2024-11-20 03:50:00 - 2024-11-20 10:30:00
# Trend keywords : 1 keywords (keyonte george)
# News tokens    : 3 tokens
# Keyword        : school closures
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-20 11:50:00 - 2024-11-20 15:10:00
# Trend keywords : 3 keywords (school closures,schools closed,weatherbug)
# News tokens    : 27 tokens
# Keyword        : fema administrator deanne criswell
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-20 15:00:00 - 2024-11-20 16:00:00
# Trend keywords : 1 keywords (fema administrator deanne criswell)
# News tokens    : 3 tokens
# Keyword        : zac taylor
# Geo            : US
# Volume         : 1000 (200%)
# Timeframe      : 2024-11-20 12:00:00 - 2024-11-20 15:40:00
# Trend keywords : 1 keywords (zac taylor)
# News tokens    : 5 tokens
# Keyword        : kyle filipowski
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 02:50:00 - 2024-11-20 08:20:00
# Trend keywords : 1 keywords (kyle filipowski)
# News tokens    : 5 tokens
# Keyword        : brasil x uruguai
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-19 23:50:00 - 2024-11-20 12:20:00
# Trend keywords : 2 keywords (brasil x uruguai,igor jesus)
# News tokens    : 5 tokens
# Keyword        : gma deals and steals
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 13:20:00 - 2024-11-20 14:30:00
# Trend keywords : 3 keywords (gma deals and steals,gma deals and steals today...)
# News tokens    : 5 tokens
# Keyword        : mta
# Geo            : US
# Volume         : 1000 (100%)
# Timeframe      : 2024-11-20 11:40:00 - 2024-11-20 14:10:00
# Trend keywords : 1 keywords (mta)
# News tokens    : 5 tokens
# Keyword        : orlando weather
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 11:00:00 - 2024-11-20 13:30:00
# Trend keywords : 3 keywords (orlando weather,radar,tallahassee weather)
# News tokens    : 14 tokens
# Keyword        : canada vs suriname
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 00:00:00 - 2024-11-20 05:20:00
# Trend keywords : 1 keywords (canada vs suriname)
# News tokens    : 1 tokens
# Keyword        : sardinia italy
# Geo            : US
# Volume         : 1000 (100%)
# Timeframe      : 2024-11-20 03:00:00 - 2024-11-20 15:00:00
# Trend keywords : 1 keywords (sardinia italy)
# News tokens    : 1 tokens
# Keyword        : valorant patch notes
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-19 18:10:00 - 2024-11-20 10:40:00
# Trend keywords : 1 keywords (valorant patch notes)
# News tokens    : 1 tokens
# Keyword        : john lithgow
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-20 14:20:00 - 2024-11-20 15:30:00
# Trend keywords : 1 keywords (john lithgow)
# News tokens    : 2 tokens
# Keyword        : iowa basketball
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 00:30:00 - 2024-11-20 03:50:00
# Trend keywords : 2 keywords (iowa basketball,iowa men's basketball)
# News tokens    : 7 tokens
# Keyword        : landman episodes
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-20 00:50:00 - 2024-11-20 05:30:00
# Trend keywords : 1 keywords (landman episodes)
# News tokens    : 3 tokens
# Keyword        : jordan clarkson
# Geo            : US
# Volume         : 2000 (200%)
# Timeframe      : 2024-11-20 03:00:00 - 2024-11-20 07:10:00
# Trend keywords : 1 keywords (jordan clarkson)
# News tokens    : 6 tokens
# Keyword        : hungría - alemania
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-19 18:50:00 - 2024-11-19 23:50:00
# Trend keywords : 1 keywords (hungría - alemania)
# News tokens    : 1 tokens
# Keyword        : concacaf nations league schedule
# Geo            : US
# Volume         : 5000 (300%)
# Timeframe      : 2024-11-20 04:20:00 - 2024-11-20 12:20:00
# Trend keywords : 4 keywords (concacaf nations league schedule,concacaf natio...)
# News tokens    : 2 tokens
# Keyword        : ohio state basketball
# Geo            : US
# Volume         : 5000 (400%)
# Timeframe      : 2024-11-20 00:10:00 - 2024-11-20 03:00:00
# Trend keywords : 2 keywords (ohio state basketball,evansville vs ohio state)
# News tokens    : 3 tokens
# Keyword        : disney cruise
# Geo            : US
# Volume         : 5000 (50%)
# Timeframe      : 2024-11-20 11:10:00 - 2024-11-20 14:40:00
# Trend keywords : 4 keywords (disney cruise,disney treasure,disney treasure c...)
# News tokens    : 28 tokens
# Keyword        : social security changes 2025
# Geo            : US
# Volume         : 1000 (75%)
# Timeframe      : 2024-11-20 13:50:00 - 2024-11-20 15:10:00
# Trend keywords : 2 keywords (social security changes 2025,2025 social securi...)
# News tokens    : 5 tokens
# Keyword        : daniel penny
# Geo            : US
# Volume         : 1000 (300%)
# Timeframe      : 2024-11-20 12:40:00 - 2024-11-20 13:50:00
# Trend keywords : 2 keywords (daniel penny,daniel penny verdict)
# News tokens    : 1 tokens
# Keyword        : phil shea
# Geo            : US
# Volume         : 5000 (400%)
# Timeframe      : 2024-11-20 01:20:00 - 2024-11-20 05:30:00
# Trend keywords : 1 keywords (phil shea)
# News tokens    : 1 tokens
# Keyword        : mike evans
# Geo            : US
# Volume         : 1000 (50%)
# Timeframe      : 2024-11-20 09:00:00 - 2024-11-20 16:10:00
# Trend keywords : 1 keywords (mike evans)
# News tokens    : 5 tokens
# Keyword        : venezuela
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-19 23:30:00 - 2024-11-20 03:10:00
# Trend keywords : 1 keywords (venezuela)
# News tokens    : 8 tokens
# Keyword        : craig porter jr.
# Geo            : US
# Volume         : 5000 (200%)
# Timeframe      : 2024-11-20 00:40:00 - 2024-11-20 04:20:00
# Trend keywords : 2 keywords (craig porter jr.,craig porter jr)
# News tokens    : 2 tokens
# Keyword        : stephen vogt
# Geo            : US
# Volume         : 5000 (100%)
# Timeframe      : 2024-11-19 23:30:00 - 2024-11-20 11:50:00
# Trend keywords : 4 keywords (stephen vogt,pat murphy,nl manager of the year ...)
# News tokens    : 9 tokens
# Keyword        : plane crash chattanooga
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-20 00:00:00 - 2024-11-20 04:20:00
# Trend keywords : 1 keywords (plane crash chattanooga)
# News tokens    : 2 tokens
# Keyword        : bay news 9
# Geo            : US
# Volume         : 1000 (75%)
# Timeframe      : 2024-11-20 09:50:00 - 2024-11-20 13:00:00
# Trend keywords : 2 keywords (bay news 9,klystron 9)
# News tokens    : 6 tokens
# Keyword        : weather chicago
# Geo            : US
# Volume         : 2000 (75%)
# Timeframe      : 2024-11-20 11:20:00 - 2024-11-20 13:40:00
# Trend keywords : 2 keywords (weather chicago,chicago weather)
# News tokens    : 3 tokens
# Keyword        : jalen williams
# Geo            : US
# Volume         : 2000 (300%)
# Timeframe      : 2024-11-20 03:30:00 - 2024-11-20 06:00:00
# Trend keywords : 2 keywords (jalen williams,jaylin williams)
# News tokens    : 5 tokens
# Keyword        : fox nation
# Geo            : US
# Volume         : 2000 (100%)
# Timeframe      : 2024-11-19 23:00:00 - 2024-11-20 13:30:00
# Trend keywords : 1 keywords (fox nation)
# News tokens    : 2 tokens
# Keyword        : david morrell
# Geo            : US
# Volume         : 2000 (50%)
# Timeframe      : 2024-11-20 00:40:00 - 2024-11-20 11:00:00
# ...
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 11:30:00 - 2024-11-20 12:40:00
# Trend keywords : 1 keywords (clima hoy)
# News tokens    : 4 tokens
# Keyword        : caracol tv
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-19 23:10:00 - 2024-11-20 00:20:00
# Trend keywords : 1 keywords (caracol tv)
# News tokens    : 2 tokens
# Keyword        : pat riley
# Geo            : US
# Volume         : 200 (75%)
# Timeframe      : 2024-11-20 05:00:00 - 2024-11-20 06:10:00
# Trend keywords : 1 keywords (pat riley)
# News tokens    : 3 tokens
# Keyword        : george strait
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-20 01:20:00 - 2024-11-20 02:20:00
# Trend keywords : 1 keywords (george strait)
# News tokens    : 6 tokens
# Keyword        : gabe vincent
# Geo            : US
# Volume         : 200 (75%)
# Timeframe      : 2024-11-20 05:50:00 - 2024-11-20 07:00:00
# Trend keywords : 1 keywords (gabe vincent)
# News tokens    : 2 tokens
# Keyword        : knox county
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-20 03:40:00 - 2024-11-20 04:30:00
# Trend keywords : 1 keywords (knox county)
# News tokens    : 9 tokens
# Keyword        : alvin bragg
# Geo            : US
# Volume         : 1000 (100%)
# Timeframe      : 2024-11-19 18:20:00 - 2024-11-19 19:30:00
# Trend keywords : 2 keywords (alvin bragg,judge merchan)
# News tokens    : 8 tokens
# Keyword        : kelly monaco
# Geo            : US
# Volume         : 1000 (50%)
# Timeframe      : 2024-11-19 19:50:00 - 2024-11-19 21:20:00
# Trend keywords : 1 keywords (kelly monaco)
# News tokens    : 4 tokens
# Keyword        : marissa bode
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 03:30:00 - 2024-11-20 04:30:00
# Trend keywords : 1 keywords (marissa bode)
# News tokens    : 3 tokens
# Keyword        : andrew sullivan
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 02:00:00 - 2024-11-20 03:00:00
# Trend keywords : 1 keywords (andrew sullivan)
# News tokens    : 1 tokens
# Keyword        : lala kent
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 03:30:00 - 2024-11-20 04:30:00
# Trend keywords : 1 keywords (lala kent)
# News tokens    : 7 tokens
# Keyword        : shiloh pitt
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-20 01:10:00 - 2024-11-20 02:00:00
# Trend keywords : 1 keywords (shiloh pitt)
# News tokens    : 3 tokens
# Keyword        : niang
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 01:40:00 - 2024-11-20 02:40:00
# Trend keywords : 1 keywords (niang)
# News tokens    : 2 tokens
# Keyword        : celtic
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 02:10:00 - 2024-11-20 03:10:00
# Trend keywords : 1 keywords (celtic)
# News tokens    : 13 tokens
# Keyword        : deer hunting
# Geo            : US
# Volume         : 1000 (50%)
# Timeframe      : 2024-11-19 17:50:00 - 2024-11-19 19:10:00
# Trend keywords : 1 keywords (deer hunting)
# News tokens    : 14 tokens
# Keyword        : new jersey lottery
# Geo            : US
# Volume         : 100 (75%)
# Timeframe      : 2024-11-20 10:30:00 - 2024-11-20 11:30:00
# Trend keywords : 1 keywords (new jersey lottery)
# News tokens    : 5 tokens
# Keyword        : midland texas
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 02:40:00 - 2024-11-20 03:40:00
# Trend keywords : 1 keywords (midland texas)
# News tokens    : 2 tokens
# Keyword        : dylan dreyer
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-19 23:50:00 - 2024-11-20 00:50:00
# Trend keywords : 1 keywords (dylan dreyer)
# News tokens    : 3 tokens
# Keyword        : grant williams
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 02:50:00 - 2024-11-20 03:50:00
# Trend keywords : 1 keywords (grant williams)
# News tokens    : 7 tokens
# Keyword        : boise state conference
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-20 00:40:00 - 2024-11-20 01:30:00
# Trend keywords : 1 keywords (boise state conference)
# News tokens    : 2 tokens
# Keyword        : jonathan isaac
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 04:30:00 - 2024-11-20 05:30:00
# Trend keywords : 1 keywords (jonathan isaac)
# News tokens    : 2 tokens
# Keyword        : bethel ohio
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-19 23:40:00 - 2024-11-20 00:50:00
# Trend keywords : 1 keywords (bethel ohio)
# News tokens    : 1 tokens
# Keyword        : paolo guerrero
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 00:20:00 - 2024-11-20 01:20:00
# Trend keywords : 1 keywords (paolo guerrero)
# News tokens    : 4 tokens
# Keyword        : pacific power
# Geo            : US
# Volume         : 200 (75%)
# Timeframe      : 2024-11-20 04:40:00 - 2024-11-20 05:30:00
# Trend keywords : 1 keywords (pacific power)
# News tokens    : 2 tokens
# Keyword        : sean connery
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 00:00:00 - 2024-11-20 01:00:00
# Trend keywords : 1 keywords (sean connery)
# News tokens    : 2 tokens
# Keyword        : brownsville tx
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-19 21:50:00 - 2024-11-19 22:50:00
# Trend keywords : 1 keywords (brownsville tx)
# News tokens    : 5 tokens
# Keyword        : giuliano simeone
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 01:50:00 - 2024-11-20 02:50:00
# Trend keywords : 1 keywords (giuliano simeone)
# News tokens    : 4 tokens
# Keyword        : minneapolis weather
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 11:10:00 - 2024-11-20 12:10:00
# Trend keywords : 1 keywords (minneapolis weather)
# News tokens    : 1 tokens
# Keyword        : amy grant
# Geo            : US
# Volume         : 200 (100%)
# Timeframe      : 2024-11-20 06:00:00 - 2024-11-20 06:50:00
# Trend keywords : 1 keywords (amy grant)
# News tokens    : 2 tokens
# Keyword        : dario šarić
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 03:30:00 - 2024-11-20 04:30:00
# Trend keywords : 1 keywords (dario šarić)
# News tokens    : 2 tokens
# Keyword        : shiloh jolie-pitt 2024
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 01:10:00 - 2024-11-20 02:00:00
# Trend keywords : 1 keywords (shiloh jolie-pitt 2024)
# News tokens    : 2 tokens
# Keyword        : mallorca
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 01:40:00 - 2024-11-20 02:30:00
# Trend keywords : 1 keywords (mallorca)
# News tokens    : 6 tokens
# Keyword        : argentine – pérou
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-19 23:40:00 - 2024-11-20 00:40:00
# Trend keywords : 1 keywords (argentine – pérou)
# News tokens    : 3 tokens
# Keyword        : bob woodward
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-19 23:40:00 - 2024-11-20 00:30:00
# Trend keywords : 1 keywords (bob woodward)
# News tokens    : 1 tokens
# Keyword        : abner vinícius
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 02:10:00 - 2024-11-20 03:10:00
# Trend keywords : 1 keywords (abner vinícius)
# News tokens    : 1 tokens
# Keyword        : dan mullen
# Geo            : US
# Volume         : 500 (100%)
# Timeframe      : 2024-11-19 18:30:00 - 2024-11-19 19:30:00
# Trend keywords : 1 keywords (dan mullen)
# News tokens    : 2 tokens
# Keyword        : maggie hassan
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-19 23:40:00 - 2024-11-20 00:40:00
# Trend keywords : 1 keywords (maggie hassan)
# News tokens    : 2 tokens
# Keyword        : 白夜破晓
# Geo            : US
# Volume         : 100 (75%)
# Timeframe      : 2024-11-20 07:30:00 - 2024-11-20 08:40:00
# Trend keywords : 1 keywords (白夜破晓)
# News tokens    : 1 tokens
# Keyword        : longwood basketball
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 01:00:00 - 2024-11-20 01:50:00
# Trend keywords : 1 keywords (longwood basketball)
# News tokens    : 1 tokens
# Keyword        : lamelo ball injury
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 03:00:00 - 2024-11-20 03:40:00
# Trend keywords : 1 keywords (lamelo ball injury)
# News tokens    : 1 tokens
# Keyword        : kansas state basketball
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 02:50:00 - 2024-11-20 03:30:00
# Trend keywords : 1 keywords (kansas state basketball)
# News tokens    : 5 tokens
# Keyword        : where is marquette university
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 02:40:00 - 2024-11-20 03:20:00
# Trend keywords : 1 keywords (where is marquette university)
# News tokens    : 2 tokens
# Keyword        : elden ring
# Geo            : US
# Volume         : 100 (75%)
# Timeframe      : 2024-11-20 09:00:00 - 2024-11-20 10:00:00
# Trend keywords : 1 keywords (elden ring)
# News tokens    : 10 tokens
# Keyword        : sicario
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 06:30:00 - 2024-11-20 07:20:00
# Trend keywords : 1 keywords (sicario)
# News tokens    : 9 tokens
# Keyword        : walker kessler
# Geo            : US
# Volume         : 200 (75%)
# Timeframe      : 2024-11-20 06:00:00 - 2024-11-20 06:40:00
# Trend keywords : 1 keywords (walker kessler)
# News tokens    : 4 tokens
# Keyword        : mexico vs canada
# Geo            : US
# Volume         : 200 (75%)
# Timeframe      : 2024-11-20 05:20:00 - 2024-11-20 06:00:00
# Trend keywords : 1 keywords (mexico vs canada)
# News tokens    : 1 tokens
# Keyword        : joel leppard
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 03:40:00 - 2024-11-20 04:20:00
# Trend keywords : 1 keywords (joel leppard)
# News tokens    : 1 tokens
# Keyword        : lucky for life
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 10:30:00 - 2024-11-20 11:20:00
# Trend keywords : 1 keywords (lucky for life)
# News tokens    : 6 tokens
# Keyword        : diesel
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 08:40:00 - 2024-11-20 09:40:00
# Trend keywords : 1 keywords (diesel)
# News tokens    : 16 tokens
# Keyword        : how old is karoline leavitt
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 02:30:00 - 2024-11-20 03:10:00
# Trend keywords : 1 keywords (how old is karoline leavitt)
# News tokens    : 1 tokens
# Keyword        : ky lottery
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 10:40:00 - 2024-11-20 11:20:00
# Trend keywords : 1 keywords (ky lottery)
# News tokens    : 1 tokens
# Keyword        : bindi irwin news
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 12:20:00 - 2024-11-20 12:40:00
# Trend keywords : 1 keywords (bindi irwin news)
# News tokens    : 4 tokens
# Keyword        : ucf basketball
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 02:20:00 - 2024-11-20 02:50:00
# Trend keywords : 1 keywords (ucf basketball)
# News tokens    : 4 tokens
# Keyword        : woody harrelson
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 06:20:00 - 2024-11-20 08:10:00
# Trend keywords : 1 keywords (woody harrelson)
# News tokens    : 3 tokens
# Keyword        : nasa
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-19 22:10:00 - 2024-11-19 22:50:00
# Trend keywords : 1 keywords (nasa)
# News tokens    : 11 tokens
# Keyword        : nev schulman
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 02:30:00 - 2024-11-20 03:00:00
# Trend keywords : 1 keywords (nev schulman)
# News tokens    : 3 tokens
# Keyword        : nba jokic
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 05:00:00 - 2024-11-20 05:40:00
# Trend keywords : 1 keywords (nba jokic)
# News tokens    : 10 tokens
# Keyword        : target black friday 2024
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 11:10:00 - 2024-11-20 11:30:00
# Trend keywords : 1 keywords (target black friday 2024)
# News tokens    : 7 tokens
# Keyword        : santa monica high school
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-19 22:40:00 - 2024-11-19 23:20:00
# Trend keywords : 1 keywords (santa monica high school)
# News tokens    : 1 tokens
# Keyword        : usps operation santa
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 11:10:00 - 2024-11-20 11:40:00
# Trend keywords : 1 keywords (usps operation santa)
# News tokens    : 1 tokens
# Keyword        : paraguay
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-19 22:10:00 - 2024-11-19 22:50:00
# Trend keywords : 1 keywords (paraguay)
# News tokens    : 7 tokens
# Keyword        : harris dickinson
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 05:40:00 - 2024-11-20 06:20:00
# Trend keywords : 1 keywords (harris dickinson)
# News tokens    : 5 tokens
# Keyword        : william shatner
# Geo            : US
# Volume         : 500 (75%)
# Timeframe      : 2024-11-20 00:40:00 - 2024-11-20 01:10:00
# Trend keywords : 1 keywords (william shatner)
# News tokens    : 5 tokens
# Keyword        : alex cross tv series
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 02:50:00 - 2024-11-20 03:20:00
# Trend keywords : 1 keywords (alex cross tv series)
# News tokens    : 1 tokens
# Keyword        : seatac airport
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 06:20:00 - 2024-11-20 07:00:00
# Trend keywords : 1 keywords (seatac airport)
# News tokens    : 4 tokens
# Keyword        : photos
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 10:10:00 - 2024-11-20 10:50:00
# Trend keywords : 1 keywords (photos)
# News tokens    : 12 tokens
# Keyword        : georgia power
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 11:10:00 - 2024-11-20 11:30:00
# Trend keywords : 1 keywords (georgia power)
# News tokens    : 3 tokens
# Keyword        : cason wallace
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 05:10:00 - 2024-11-20 05:40:00
# Trend keywords : 1 keywords (cason wallace)
# News tokens    : 2 tokens
# Keyword        : nba rookie of the year odds
# Geo            : US
# Volume         : 200 (50%)
# Timeframe      : 2024-11-20 06:00:00 - 2024-11-20 06:30:00
# Trend keywords : 1 keywords (nba rookie of the year odds)
# News tokens    : 4 tokens
# Keyword        : prince
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 08:10:00 - 2024-11-20 08:40:00
# Trend keywords : 1 keywords (prince)
# News tokens    : 14 tokens
# Keyword        : red dead redemption 2
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 07:20:00 - 2024-11-20 07:50:00
# Trend keywords : 1 keywords (red dead redemption 2)
# News tokens    : 12 tokens
# Keyword        : cyberpunk
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 07:30:00 - 2024-11-20 08:00:00
# Trend keywords : 1 keywords (cyberpunk)
# News tokens    : 13 tokens
# Keyword        : tyla
# Geo            : US
# Volume         : 200 (75%)
# Timeframe      : 2024-11-20 07:50:00 - 2024-11-20 08:10:00
# Trend keywords : 1 keywords (tyla)
# News tokens    : 4 tokens
# Keyword        : fa
# Geo            : US
# Volume         : 100 (50%)
# Timeframe      : 2024-11-20 08:40:00 - 2024-11-20 09:00:00
# Trend keywords : 1 keywords (fa)
# News tokens    : 15 tokens
# Keyword        : binghamton university
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-20 01:10:00 - 2024-11-20 01:30:00
# Trend keywords : 1 keywords (binghamton university)
# News tokens    : 8 tokens
# Keyword        : nih
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-19 20:40:00 - 2024-11-19 21:00:00
# Trend keywords : 1 keywords (nih)
# News tokens    : 13 tokens
# Keyword        : aaron rodgers contract
# Geo            : US
# Volume         : 500 (50%)
# Timeframe      : 2024-11-19 18:00:00 - 2024-11-19 18:20:00
# Trend keywords : 1 keywords (aaron rodgers contract)
# News tokens    : 1 tokens

# %%
from trendspy import Trends

# Initialize the API client
tr = Trends()
trends_tech = list(filter(lambda item: 18 in item.topics, trending_now_us))
news = tr.trending_now_news_by_ids(trends_tech[0].news_tokens, max_news=3)

for news_item in news:
    print(news_item, '\n')
# Out:
# Title   : The PlayStation Portal remote player experience to evolve with new system
# update
# URL     : https://blog.playstation.com/2024/11/19/the-playstation-portal-remote-player-experience-to-evolve-with-new-system-update/
# Source  : PlayStation.Blog
# Picture : https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSryCVqCkH3eSK4ZBMfRHGGYV0T5BzMAtb3nZPPc3r8z-qZZbuvL29C4gJxi2w
# Time    : 2024-11-19 22:00:03
#
# Title   : Sony Finally Turns the PlayStation Portal Into the Handheld Streamer We
# Always Wanted
# URL     : https://gizmodo.com/playstation-portal-handheld-streamer-2000526956
# Source  : Gizmodo
# Picture : https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSUl30RWz_prVA6Jj1Aui9-b6R3fvFwo-8_NpbN7sA5eZ7rC29E4vu0eh_S5k4
# Time    : 2024-11-20 15:50:30
#
# Title   : Sony’s new PlayStation Portal update lets you stream PS5 games from the
# cloud
# URL     : https://www.theverge.com/2024/11/19/24300991/playstation-portal-cloud-streaming-update-beta-ps5-games
# Source  : The Verge
# Picture : https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQUW8m5qyBBvqh24_IgZi5U98VEvE1QdhtGwTMM50O7AclUGxHHyHiuYIqo_TM
# Time    : 2024-11-19 22:22:33

# %% [markdown]
# ### Testing unified fetch_trending_data function

# %%
import time 

@time_it
def fetch_trending_data():
    """
    Fetch trending data and related news articles, merge the results into a DataFrame.
    
    This function:
    1. Retrieves trending topics using the `trending_now` method.
    2. Limits the size of the resulting DataFrame to 100 entries.
    3. Fetches news articles for each trending topic using the `trending_now_news_by_ids` method.
    4. Combines the news data with the trending topics.
    
    Returns:
        pandas.DataFrame: DataFrame containing the merged trending data, with columns:
            - Keyword: The trending keyword.
            - Volume: The search volume for the keyword.
            - Timeframe: The time range during which the keyword has been trending.
            - Trend keywords: The first 10 related keywords.
            - News articles: Titles, URLs, and other details of related news articles.
    """
    try:
        # Fetch trending topics
        trending_now_data = tr.trending_now(geo='US')

        # Limit the size of the trending topics to 100
        trending_now_data = trending_now_data[:3]

        # Log the raw data structure for debugging
        # logging.info(f"Raw trending data: {trending_now_data}")

        # Initialize a list to store data
        data = []

        # Process each TrendKeyword object
        for trend in trending_now_data:
            # Extract basic information about the trend
            keyword = trend.keyword
            volume = trend.volume
            timeframe = f"{trend._convert_to_datetime(trend.started_timestamp[0]).strftime('%Y-%m-%d %H:%M:%S')} - " \
                        f"{trend._convert_to_datetime(trend.ended_timestamp[0]).strftime('%Y-%m-%d %H:%M:%S') if trend.is_trend_finished else 'now'}"
            trend_keywords = ', '.join(trend.trend_keywords[:10]) if trend.trend_keywords else 'No related keywords'

            # Fetch news articles related to the trend using `trending_now_news_by_ids`
            news_articles_data = tr.trending_now_news_by_ids(trend.news_tokens, max_news=5)
            news_articles = []
            for article in news_articles_data:
                news_articles.append(f"{article.title} ({article.source}) - {article.url}")
                time.sleep(0.5)

            # Combine all news articles into a single string
            news_articles_str = '; '.join(news_articles) if news_articles else 'No articles'

            # Append the extracted data to the list
            data.append({
                'Keyword': keyword,
                'Volume': volume,
                'Timeframe': timeframe,
                'Trend keywords': trend_keywords,
                'News articles': news_articles_str
            })

        # Convert the list of data into a pandas DataFrame
        trending_df = pd.DataFrame(data)

        return trending_df

    except Exception as e:
        # Log the detailed error for debugging
        logging.error("An error occurred while fetching trending data.", exc_info=True)
        return pd.DataFrame()  # Return an empty DataFrame on error

# %%
import time
from functools import wraps

def time_it(func):
    """
    A decorator that measures and prints the time taken by a function to complete.
    
    Args:
        func (callable): The function to be decorated.
    
    Returns:
        callable: The wrapped function with timing functionality.
    """
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()  # Record the start time
        result = func(*args, **kwargs)  # Call the wrapped function
        end_time = time.time()  # Record the end time
        duration = end_time - start_time  # Calculate the duration
        print(f"Function '{func.__name__}' completed in {duration:.2f} seconds.")
        return result  # Return the result of the function
    return wrapper

# %%
#execution time for 3 results
data = fetch_trending_data()
# Out:
# Function 'fetch_trending_data' completed in 7.88 seconds.

# %%
data
# Out:
#           Keyword  Volume                  Timeframe  \
# 0   linda mcmahon  500000  2024-11-19 20:40:00 - now
# 1           dr oz  500000  2024-11-19 20:50:00 - now
# 2  pse outage map  500000  2024-11-19 23:00:00 - now
#
#                                       Trend keywords  \
# 0  linda mcmahon, linda mcmahon education, vince ...
# 1  dr oz, dr. oz, dr oz trump, mehmet oz, dr oz m...
# 2  pse outage map, bay, puget sound energy, power...
#
#                                        News articles
# 0  Trump names Linda McMahon as his pick for Educ...
# 1  Fetterman would be willing to confirm Dr. Oz —...
# 2  A new threat arrives from a deadly bomb cyclon...

# %%
data['News articles'].loc[0]
# Out:
# "Trump names Linda McMahon as his pick for Education secretary (CNN) - https://www.cnn.com/2024/11/19/politics/linda-mcmahon-education-secretary-trump/index.html; Trump’s Latest Cabinet Pick Is Also Mired in a Sexual Abuse Scandal (The New Republic) - https://newrepublic.com/post/188630/linda-mcmahon-trump-cabinet-sexual-abuse-scandal; Former W.W.E. Boss Tapped to Run Education, and Trans Rights on Capitol Hill (The New York Times) - https://www.nytimes.com/2024/11/20/podcasts/trump-education-trans-rights-capitol-hill.html; Linda McMahon made a fortune with WWE. Wrestling scandals now shadow her \nrise. (The Washington Post) - https://www.washingtonpost.com/politics/2024/11/19/linda-mcmahon-trump-administration-wwe-allegations/; Betsy DeVos praises Linda McMahon as 'great appointment' to lead Trump's \nEducation Department (Fox News) - https://www.foxnews.com/video/6364953486112"

# %%
data = fetch_trending_data()
# Out:
# 2024-11-20 17:32:18,990 - INFO - Raw trending data: [TrendKeyword(keyword='linda mcmahon', geo='US', volume=500000, started_timestamp=[1732048800], ended_timestamp=None), TrendKeyword(keyword='dr oz', geo='US', volume=500000, started_timestamp=[1732049400], ended_timestamp=None), TrendKeyword(keyword='pse outage map', geo='US', volume=500000, started_timestamp=[1732057200], ended_timestamp=None), TrendKeyword(keyword='dalton knecht', geo='US', volume=200000, started_timestamp=[1732077000], ended_timestamp=None), TrendKeyword(keyword='jay leno', geo='US', volume=50000, started_timestamp=[1732047000], ended_timestamp=None), TrendKeyword(keyword='méxico - honduras', geo='US', volume=500000, started_timestamp=[1732067400], ended_timestamp=None), TrendKeyword(keyword='liam payne funeral', geo='US', volume=20000, started_timestamp=[1732092000], ended_timestamp=None), TrendKeyword(keyword='brazil vs uruguay', geo='US', volume=200000, started_timestamp=[1732050600], ended_timestamp=None), TrendKeyword(keyword='argentina vs peru', geo='US', volume=200000, started_timestamp=[1732047600], ended_timestamp=None), TrendKeyword(keyword='group of musical notes', geo='US', volume=20000, started_timestamp=[1732072200], ended_timestamp=None), TrendKeyword(keyword='magnetic north pole moving', geo='US', volume=20000, started_timestamp=[1732041000], ended_timestamp=None), TrendKeyword(keyword='target stock', geo='US', volume=20000, started_timestamp=[1732102800], ended_timestamp=None), TrendKeyword(keyword='seattle city light outage map', geo='US', volume=20000, started_timestamp=[1732065600], ended_timestamp=None), TrendKeyword(keyword='jazz vs lakers', geo='US', volume=50000, started_timestamp=[1732072200], ended_timestamp=None), TrendKeyword(keyword='susan smith', geo='US', volume=20000, started_timestamp=[1732045200], ended_timestamp=None), TrendKeyword(keyword='jose ibarra', geo='US', volume=20000, started_timestamp=[1732073400], ended_timestamp=None), TrendKeyword(keyword='minecraft movie', geo='US', volume=20000, started_timestamp=[1732047600], ended_timestamp=None), TrendKeyword(keyword='healthcare provider bankruptcies', geo='US', volume=10000, started_timestamp=[1732102200], ended_timestamp=None), TrendKeyword(keyword='southern california doomsday fish', geo='US', volume=20000, started_timestamp=[1732041000], ended_timestamp=None), TrendKeyword(keyword='el carro de shakira.com', geo='US', volume=5000, started_timestamp=[1732111200], ended_timestamp=None), TrendKeyword(keyword='nvidia earnings', geo='US', volume=50000, started_timestamp=[1732048800], ended_timestamp=None), TrendKeyword(keyword='stalker 2 review', geo='US', volume=20000, started_timestamp=[1732075800], ended_timestamp=None), TrendKeyword(keyword='julianne hough', geo='US', volume=20000, started_timestamp=[1732066800], ended_timestamp=None), TrendKeyword(keyword='drones flying over morris county nj', geo='US', volume=10000, started_timestamp=[1732073400], ended_timestamp=None), TrendKeyword(keyword='richard gere', geo='US', volume=10000, started_timestamp=[1732109400], ended_timestamp=None), TrendKeyword(keyword='saafir', geo='US', volume=20000, started_timestamp=[1732042800], ended_timestamp=None), TrendKeyword(keyword='samantha robertson', geo='US', volume=20000, started_timestamp=[1732071600], ended_timestamp=None), TrendKeyword(keyword='matthew whitaker', geo='US', volume=5000, started_timestamp=[1732117200], ended_timestamp=None), TrendKeyword(keyword='jaguar car', geo='US', volume=10000, started_timestamp=[1732082400], ended_timestamp=None), TrendKeyword(keyword='nicole murphy', geo='US', volume=20000, started_timestamp=[1732063200], ended_timestamp=None), TrendKeyword(keyword='morgan freeman', geo='US', volume=5000, started_timestamp=[1732095600], ended_timestamp=None), TrendKeyword(keyword='spotify wrapped 2024', geo='US', volume=20000, started_timestamp=[1732062000], ended_timestamp=None), TrendKeyword(keyword='post malone tour 2025', geo='US', volume=10000, starte ...
# 2024-11-20 17:32:18,991 - ERROR - An error occurred while fetching trending data.
# Traceback (most recent call last):
#   File "/tmp/ipykernel_25/3135955147.py", line 25, in fetch_trending_data
#     raise ValueError("Unexpected structure of trending_now_data. Expected a list of dictionaries.")
# ValueError: Unexpected structure of trending_now_data. Expected a list of dictionaries.

# %%
print(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
